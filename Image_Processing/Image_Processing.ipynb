# %% [markdown]
# # HSL and HSV
# are two alternative representations of the RGB color model, designed in the 1970s by computer graphics researchers to more closely align with the way human vision perceives color-making attribute
#
# HSL stands for hue, saturation, and lightness, and is often also called HLS. HSV stands for hue, saturation, and value, and is also often called HSB (B for brightness). A third model, common in computer vision applications, is HSI, for hue, saturation, and intensity.

# %% [markdown]
# # Hue
# defines pure color in terms of "green", "red" or "magenta". Hue also defines mixtures of two pure colors like "red-yellow" (~ "orange"), or "yellow-green" ...
#
# Hue is usually one property of three when used to determine a certain color.
#
# Hue ranges from 0° to 359° when measured in degrees.
# Hues can refer to the set of "pure" colors within a color space.

# %% [markdown]
# # Saturation
# defines a range from pure color (100%) to gray (0%) at a constant lightness level. A pure color is fully saturated.

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img=cv2.imread("ghoda.jpg")

# %%
plt.imshow(img)

# %% [markdown]
# The blue color is due to BGR format of opencv

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
plt.imshow(img)

# %%
img=cv2.cvtColor(img,cv2.COLOR_RGB2HLS)
plt.imshow(img)

# %% [markdown]
# # Blending
# Blend modes in digital image editing and computer graphics are used to determine how two layers are blended into each other.
#
#
# Blending:
#
# Mixing two images. The output image is a combination of the corresponding pixel values of the input images.
#
# Blending images is done through the addWeighted function that uses both images and combines them.
# Formula::
#
#         new_pixel = alpha x pixel_1 + beta x pixel_2 + gamma
#
#         we can choose alphavalue stronger to make  pixel_1 higher representative
#         # # Blending
# Blend modes in digital image editing and computer graphics are used to determine how two layers are blended into each other.
#
#
# Blending:
#
# Mixing two images. The output image is a combination of the corresponding pixel values of the input images.
#
# Blending images is done through the addWeighted function that uses both images and combines them.
# Formula::
#
#
#         new_pixel = alpha x pixel_1 + beta x pixel_2 + gamma
#
#         we can choose alphavalue stronger to make  pixel_1 higher representative

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img_1=cv2.imread("ghoda.jpg")
img_1=cv2.cvtColor(img_1,cv2.COLOR_BGR2RGB)
plt.imshow(img_1)

# %%
img_2=cv2.imread("gadha.jpeg")
im_2g=cv2.cvtColor(img_2,cv2.COLOR_BGR2RGB)
plt.imshow(img_2)

# %%
img_1.shape
# Out:
# (960, 1280, 3)

# %%
img_2.shape
# Out:
# (710, 474, 3)

# %% [markdown]
# # Resizing images to blend

# %%
img_1=cv2.resize(img_1,(600,600))

# %%
img_2=cv2.resize(img_2,(600,600))

# %%
plt.imshow(img_1)

# %%
plt.imshow(img_2)

# %%
blended_img1= cv2.addWeighted(src1=img_1,alpha=0.5,src2=img_2,beta=0.8,gamma=0)

# %%
plt.imshow(blended_img1)

# %%
blended_img2= cv2.addWeighted(src1=img_1,alpha=0.1,src2=img_2,beta=0.9,gamma=0)
plt.imshow(blended_img2)

# %% [markdown]
# # Adding 2nd img in 1st img

# %%
img_1=cv2.imread("ghoda.jpg")
img_1=cv2.cvtColor(img_1,cv2.COLOR_BGR2RGB)

# %%
img_2=cv2.imread("gadha.jpeg")
im_2g=cv2.cvtColor(img_2,cv2.COLOR_BGR2RGB)

# %%
large_img=img_1
small_img=img_2

# %%
x_offset =0 
y_offset =0  #means at top left corner

# %%
x_end =x_offset +small_img.shape[1]  # 0,1 =710,474
y_end =y_offset + small_img.shape[0]  #how tall is small img

# %%
small_img.shape
# Out:
# (710, 474, 3)

# %%
large_img[y_offset:y_end,x_offset:x_end]=small_img
plt.imshow(large_img)
